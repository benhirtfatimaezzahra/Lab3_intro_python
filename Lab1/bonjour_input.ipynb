# %%
prenom=input("Quel est votre prénom ?")

print("Bonjour "+prenom)
print(f"Ravi de te rencontrer, {prenom}")
print(f"Longeur du prénom : {len(prenom)} caracteres.")
# Out:
# Bonjour fz
# Ravi de te rencontrer, fz
# Longeur du prénom : 2 caracteres.
